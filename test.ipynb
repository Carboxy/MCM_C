# %%
import pandas as pd

# %%
raw_data = pd.read_csv("data/hair_dryer.tsv", sep='\t')

# %%
raw_data
# Out:
#       marketplace  customer_id       review_id  product_id  product_parent  \
# 0              US     34678741   R9T1FE2ZX2X04  B003V264WW       732252283
# 1              US     11599505   RE36JAD5V53PO  B0009XH6V4       670161917
# 2              US      2282190   RIDHM8B7SCCV3  B0007NZPY6        16483457
# 3              US     43669858  R14QGWPCHU9LSE  B00BB8ZIW0       253917972
# 4              US       107098  R35BHQJHXXJD59  B003V264WW       732252283
# ...           ...          ...             ...         ...             ...
# 11465          US     35599734  R2O50YNP83CG34  B000065DJY       919751065
# 11466          US     43977044  R2JQPUYU65C4QD  B00005O0MZ       694290590
# 11467          US     37733836  R3GO6L5PWBS0IW  B00005O0MZ       694290590
# 11468          US     38947355  R3JMGN42OJCL97  B00005O0MZ       694290590
# 11469          US     43740490  R2XM83JYE2KDE2  B00005O0MZ       694290590
#
# ...

# %%
product = raw_data.groupby("product_parent")

# %%
product

# %%
for i in product:
    print(i)
# Out:
# (423960,       marketplace  customer_id       review_id  product_id  product_parent  \
# 461            US     37151655  R1XW9ZY9FPWSH5  B0037MFCHE          423960
# 1012           US     21789399  R281UJFH6189LK  B0037MFCHE          423960
# 1140           US     21957478  R2WDEEE7PH2SVD  B0037MFCHE          423960
# 1382           US     25707689  R1DUT4WQUCUJ4Z  B0037MFCHE          423960
# 2561           US     44514857   RCFJRHICE6322  B0037MFCHE          423960
# ...           ...          ...             ...         ...             ...
# 9127           US     43809047  R3CPKRNOPZNYJF  B0037MFCHE          423960
# 9181           US     10720769  R1SFN99369FRH3  B0037MFCHE          423960
# 9321           US     33034474  R156Q4PK1FK0NY  B0037MFCHE          423960
# 9617           US     46822429  R2YTZH2FF966R9  B0037MFCHE          423960
# 10081          US     26237444   RUQQWDWA58D65  B0037MFCHE          423960
#
# ...

# %%
p = product[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-5c432b708c69> in <module>
# ----> 1 p = product[0]
#
# D:\Anaconda\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     266         else:
#     267             if key not in self.obj:
# --> 268                 raise KeyError("Column not found: {key}".format(key=key))
#     269             return self._gotitem(key, ndim=1)
#     270
#
# KeyError: 'Column not found: 0'

# %%
product["star_rating"]

# %%
for i in product:
    print(i["star_rating"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-652a09942a15> in <module>
#       1 for i in product:
# ----> 2     print(i["star_rating"])
#
# TypeError: tuple indices must be integers or slices, not str

# %%
product["star_rating"]

# %%
product.mean()
# Out:
#                  customer_id  star_rating  helpful_votes  total_votes
# product_parent
# 423960          2.923557e+07     4.097222       0.472222     0.513889
# 4120409         3.369344e+07     5.000000       7.000000     9.000000
# 11468070        3.529190e+07     1.000000       0.000000     0.000000
# 12536427        4.779281e+07     5.000000       0.000000     0.000000
# 14552349        1.249497e+07     5.000000       3.000000     4.000000
# ...                      ...          ...            ...          ...
# 989462119       1.583294e+07     5.000000      20.000000    23.000000
# 992735618       4.346118e+07     5.000000       1.000000     2.000000
# 994490028       2.136082e+07     1.000000       0.000000     2.000000
# 995991159       1.303600e+07     4.000000       1.000000     4.000000
# 999436586       1.313601e+07     4.000000       1.000000     1.000000
#
# [473 rows x 4 columns]

# %%
product.mean()["star_rating"]
# Out:
# product_parent
# 423960       4.097222
# 4120409      5.000000
# 11468070     1.000000
# 12536427     5.000000
# 14552349     5.000000
#                ...
# 989462119    5.000000
# 992735618    5.000000
# 994490028    1.000000
# 995991159    4.000000
# 999436586    4.000000
# Name: star_rating, Length: 473, dtype: float64

# %%
product

# %%
raw_data.groupby("product_parent").get_group(423960)
# Out:
#       marketplace  customer_id       review_id  product_id  product_parent  \
# 461            US     37151655  R1XW9ZY9FPWSH5  B0037MFCHE          423960
# 1012           US     21789399  R281UJFH6189LK  B0037MFCHE          423960
# 1140           US     21957478  R2WDEEE7PH2SVD  B0037MFCHE          423960
# 1382           US     25707689  R1DUT4WQUCUJ4Z  B0037MFCHE          423960
# 2561           US     44514857   RCFJRHICE6322  B0037MFCHE          423960
# ...           ...          ...             ...         ...             ...
# 9127           US     43809047  R3CPKRNOPZNYJF  B0037MFCHE          423960
# 9181           US     10720769  R1SFN99369FRH3  B0037MFCHE          423960
# 9321           US     33034474  R156Q4PK1FK0NY  B0037MFCHE          423960
# 9617           US     46822429  R2YTZH2FF966R9  B0037MFCHE          423960
# 10081          US     26237444   RUQQWDWA58D65  B0037MFCHE          423960
#
# ...

# %%
raw_data.groupby("product_parent").get_group(423960)[]
# Out:
#   File "<ipython-input-15-41c70480337e>", line 1
#     raw_data.groupby("product_parent").get_group(423960)[]
#                                                          ^
# SyntaxError: invalid syntax

# %%
raw_data.groupby("product_parent").get_group(423960)["star_rating"]
# Out:
# 461      5
# 1012     1
# 1140     1
# 1382     5
# 2561     4
#         ..
# 9127     5
# 9181     5
# 9321     5
# 9617     5
# 10081    5
# Name: star_rating, Length: 72, dtype: int64

# %%
raw_data.groupby("product_parent").get_group(423960).groupby("star_rating")

# %%
raw_data.groupby("product_parent").get_group(423960).groupby("star_rating").count()
# Out:
#              marketplace  customer_id  review_id  product_id  product_parent  \
# star_rating
# 1                      7            7          7           7               7
# 2                      3            3          3           3               3
# 3                      7            7          7           7               7
# 4                     14           14         14          14              14
# 5                     41           41         41          41              41
#
#              product_title  product_category  helpful_votes  total_votes  \
# star_rating
# 1                        7                 7              7            7
# 2                        3                 3              3            3
# 3                        7                 7              7            7
# 4                       14                14             14           14
# 5                       41                41             41           41
#
# ...

# %%
raw_data.groupby("product_parent").get_group(423960)["st"]

# %%
raw_data.groupby("product_parent").get_group(423960)["star_rating"].to_dict()
# Out:
# {461: 5,
#  1012: 1,
#  1140: 1,
#  1382: 5,
#  2561: 4,
#  2968: 5,
#  3036: 5,
#  3514: 5,
#  4075: 5,
#  4126: 1,
#  4223: 1,
#  4448: 4,
#  4494: 4,
#  4954: 2,
#  5330: 5,
#  5433: 5,
#  5592: 4,
#  5679: 5,
#  5716: 5,
#  5792: 1,
#  5993: 3,
#  6039: 5,
#  6079: 5,
#  6146: 5,
#  6195: 4,
#  6229: 5,
#  6295: 1,
#  6349: 5,
#  6376: 3,
#  6664: 5,
#  6685: 3,
#  6798: 3,
#  6968: 4,
#  7016: 5,
#  7053: 5,
#  7109: 5,
#  7124: 5,
#  7180: 4,
#  7197: 3,
#  7204: 5,
#  7262: 5,
#  7376: 4,
#  7390: 4,
#  7429: 5,
#  7630: 5,
#  7632: 5,
#  7742: 2,
#  7769: 5,
#  7844: 5,
#  7860: 1,
#  8100: 5,
#  8210: 5,
#  8240: 4,
#  8244: 5,
#  8292: 5,
#  8332: 5,
#  8370: 4,
#  8389: 5,
#  8421: 2,
#  8550: 4,
#  8652: 5,
#  8672: 5,
#  8831: 3,
#  9055: 4,
#  9068: 3,
#  9086: 4,
#  9102: 5,
#  9127: 5,
#  9181: 5,
#  9321: 5,
#  9617: 5,
#  10081: 5}

# %%
raw_data.groupby("product_parent").get_group(423960)["review_body"].tolist()
# Out:
# ["Perhaps it's strange coming from me, but I've purchased 2 of these and it's still my favorite blow dryer!<br />I used this dryer for more than 4 years and never had a problem.<br />I purchased a second one because I gave the first one to my fiance', who lives in Japan!<br />Her mom fell in love with it, didn't bring it to the States so I had to buy yet another ConAir blow dryer :).<br />But now she has my second one, and won't accept the ConAir Infiniti Pro I bought for her.<br />Too bad, because I miss my cordless action :(<br />But I can still blow dry my hair after taking the braids out, because this is by far the best dryer ever.",
#  'Less than two years of use and this thing just stopped working. Aggravating!',
#  "Doesn't fold!!!!!",
#  'The retractable cord is wonderful for storage.  Power is great.',
# ...

# %%
t = "abc"

# %%
t.replace("a", "e")
# Out:
# 'ebc'

# %%
t
# Out:
# 'abc'

# %%
a = {1:2,2:3,5:6,3:7}

# %%
sorted(a)
# Out:
# [1, 2, 3, 5]

# %%
raw_data["review_body"].tolist()
# Out:
# ['Works great!',
#  "This dries my hair faster that bigger, more powerful models. I love travel blow dryers because they are easy to lift and they usually come in 1600 w or less. Bigger dryers are heavy and blow my hair everywhere. This has a surprising amount of power and is very compact. I would give it a five except that the switch is not easy to turn on and off with one hand and it's noisier than I anticipated.",
#  'Love this dryer!',
#  'styling hair in style',
#  "I just got this last week. I think's great. The cord length is perfect.",
#  'Excellent dryer.',
#  'Gets extremely hot - I have burned my hand on both the metal grate as well as the plastic body. After use I have to keep on the counter because it is too hot to put away. It has melted 2 different combs and now starts to smoke during use. My hair requires high heat to dry completely and not be frizzy, but this is unsafe and ridiculous. As soon as my new model arrives (not this brand) this is going in the trash!',
# ...

# %%
from nltk.tokenize import RegexpTokenizer

# %%
reviews = raw_data["review_body"].tolist()

# %%
tokenizer = RegexpTokenizer(r'\w+')

# %%
tokenizer(reviews[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-cc9ac6048c19> in <module>
# ----> 1 tokenizer(reviews[0])
#
# TypeError: 'RegexpTokenizer' object is not callable

# %%
tokenizer.tokenize(reviews[0])
# Out:
# ['Works', 'great']

# %%
tokenizer.tokenize(reviews[1])
# Out:
# ['This',
#  'dries',
#  'my',
#  'hair',
#  'faster',
#  'that',
#  'bigger',
#  'more',
#  'powerful',
#  'models',
#  'I',
#  'love',
#  'travel',
#  'blow',
#  'dryers',
#  'because',
#  'they',
#  'are',
#  'easy',
#  'to',
#  'lift',
#  'and',
#  'they',
#  'usually',
#  'come',
#  'in',
#  '1600',
#  'w',
#  'or',
#  'less',
#  'Bigger',
#  'dryers',
#  'are',
#  'heavy',
#  'and',
#  'blow',
#  'my',
#  'hair',
#  'everywhere',
#  'This',
#  'has',
#  'a',
#  'surprising',
#  'amount',
#  'of',
#  'power',
#  'and',
#  'is',
#  'very',
#  'compact',
#  'I',
#  'would',
#  'give',
#  'it',
#  'a',
#  'five',
#  'except',
#  'that',
#  'the',
#  'switch',
#  'is',
#  'not',
#  'easy',
#  'to',
#  'turn',
#  'on',
#  'and',
#  'off',
#  'with',
#  'one',
#  'hand',
#  'and',
#  'it',
#  's',
#  'noisier',
#  'than',
#  'I',
#  'anticipated']

# %%
reviews = df["review_body"].tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-8de1efb59f7e> in <module>
# ----> 1 reviews = df["review_body"].tolist()
#
# NameError: name 'df' is not defined

# %%
reviews = raw_data["review_body"].tolist()

# %%
tokenizer = RegexpTokenizer(r'\w+')
tokens_list = []

for review in reviews:
    tokens = tokenizer.tokenize(review)
    tokens_list.append(tokens)

# %%
token_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-ad6b38943148> in <module>
# ----> 1 token_list
#
# NameError: name 'token_list' is not defined

# %%
tokens_list
# Out:
# [['Works', 'great'],
#  ['This',
#   'dries',
#   'my',
#   'hair',
#   'faster',
#   'that',
#   'bigger',
#   'more',
#   'powerful',
#   'models',
#   'I',
#   'love',
#   'travel',
#   'blow',
#   'dryers',
#   'because',
#   'they',
#   'are',
#   'easy',
#   'to',
#   'lift',
#   'and',
#   'they',
#   'usually',
#   'come',
#   'in',
#   '1600',
#   'w',
#   'or',
#   'less',
#   'Bigger',
#   'dryers',
#   'are',
#   'heavy',
#   'and',
#   'blow',
#   'my',
#   'hair',
#   'everywhere',
#   'This',
#   'has',
#   'a',
#   'surprising',
#   'amount',
#   'of',
#   'power',
#   'and',
#   'is',
#   'very',
#   'compact',
#   'I',
#   'would',
#   'give',
#   'it',
#   'a',
#   'five',
#   'except',
#   'that',
#   'the',
#   'switch',
#   'is',
#   'not',
#   'easy',
#   'to',
#   'turn',
#   'on',
#   'and',
#   'off',
#   'with',
#   'one',
#   'hand',
#   'and',
#   'it',
#   's',
#   'noisier',
#   'than',
#   'I',
#   'anticipated'],
#  ['Love', 'this', 'dryer'],
# ...

# %%
import nltk

# %%
tokens_list = []

for review in reviews:
    tokens = nltk.word_tokenize(re.sub('[^\w ]', '', review))
    tokens_list.append(tokens)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-c8cda5033f98> in <module>
#       2
#       3 for review in reviews:
# ----> 4     tokens = nltk.word_tokenize(re.sub('[^\w ]', '', review))
#       5     tokens_list.append(tokens)
#
# NameError: name 're' is not defined

# %%
import re

# %%
tokens_list = []

for review in reviews:
    tokens = nltk.word_tokenize(re.sub('[^\w ]', '', review))
    tokens_list.append(tokens)

# %%
print(tokens_list)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(tokens_list[0])
# Out:
# ['Works', 'great']

# %%
print(tokens_list[1])
# Out:
# ['This', 'dries', 'my', 'hair', 'faster', 'that', 'bigger', 'more', 'powerful', 'models', 'I', 'love', 'travel', 'blow', 'dryers', 'because', 'they', 'are', 'easy', 'to', 'lift', 'and', 'they', 'usually', 'come', 'in', '1600', 'w', 'or', 'less', 'Bigger', 'dryers', 'are', 'heavy', 'and', 'blow', 'my', 'hair', 'everywhere', 'This', 'has', 'a', 'surprising', 'amount', 'of', 'power', 'and', 'is', 'very', 'compact', 'I', 'would', 'give', 'it', 'a', 'five', 'except', 'that', 'the', 'switch', 'is', 'not', 'easy', 'to', 'turn', 'on', 'and', 'off', 'with', 'one', 'hand', 'and', 'its', 'noisier', 'than', 'I', 'anticipated']

# %%
print(tokens_list[2])
# Out:
# ['Love', 'this', 'dryer']

# %%
print(tokens_list[3])
# Out:
# ['styling', 'hair', 'in', 'style']

# %%
print(tokens_list[4])
# Out:
# ['I', 'just', 'got', 'this', 'last', 'week', 'I', 'thinks', 'great', 'The', 'cord', 'length', 'is', 'perfect']

# %%
print(tokens_list[6])
# Out:
# ['Gets', 'extremely', 'hot', 'I', 'have', 'burned', 'my', 'hand', 'on', 'both', 'the', 'metal', 'grate', 'as', 'well', 'as', 'the', 'plastic', 'body', 'After', 'use', 'I', 'have', 'to', 'keep', 'on', 'the', 'counter', 'because', 'it', 'is', 'too', 'hot', 'to', 'put', 'away', 'It', 'has', 'melted', '2', 'different', 'combs', 'and', 'now', 'starts', 'to', 'smoke', 'during', 'use', 'My', 'hair', 'requires', 'high', 'heat', 'to', 'dry', 'completely', 'and', 'not', 'be', 'frizzy', 'but', 'this', 'is', 'unsafe', 'and', 'ridiculous', 'As', 'soon', 'as', 'my', 'new', 'model', 'arrives', 'not', 'this', 'brand', 'this', 'is', 'going', 'in', 'the', 'trash']

# %%
print(tokens_list[9])
# Out:
# ['I', 'really', 'like', 'this', 'hairdryer', 'I', 'havent', 'had', 'it', 'very', 'long', 'But', 'its', 'working', 'well', 'for', 'me']

# %%
a = "UIGIUGIguiguiog89yu89"

# %%
a.lower()
# Out:
# 'uigiugiguiguiog89yu89'

# %%
a
# Out:
# 'UIGIUGIguiguiog89yu89'

# %%
import os

# %%
os.path.abspath("")
# Out:
# 'C:\\Users\\LENOVO\\Desktop\\Problem_C_Data'

# %%
import pandas

# %%
raw_data[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-26dc1a79f205> in <module>
# ----> 1 raw_data[0]
#
# ...

# %%
for index, row in raw_data.iterrows():
    row["score"] = 5

# %%
raw_data
# Out:
#       marketplace  customer_id       review_id  product_id  product_parent  \
# 0              US     34678741   R9T1FE2ZX2X04  B003V264WW       732252283
# 1              US     11599505   RE36JAD5V53PO  B0009XH6V4       670161917
# 2              US      2282190   RIDHM8B7SCCV3  B0007NZPY6        16483457
# 3              US     43669858  R14QGWPCHU9LSE  B00BB8ZIW0       253917972
# 4              US       107098  R35BHQJHXXJD59  B003V264WW       732252283
# ...           ...          ...             ...         ...             ...
# 11465          US     35599734  R2O50YNP83CG34  B000065DJY       919751065
# 11466          US     43977044  R2JQPUYU65C4QD  B00005O0MZ       694290590
# 11467          US     37733836  R3GO6L5PWBS0IW  B00005O0MZ       694290590
# 11468          US     38947355  R3JMGN42OJCL97  B00005O0MZ       694290590
# 11469          US     43740490  R2XM83JYE2KDE2  B00005O0MZ       694290590
#
# ...

# %%
raw_data.loc('1')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-b0eb8a32ff84> in <module>
# ----> 1 raw_data.loc('1')
#
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     110
#     111         if axis is not None:
# --> 112             axis = self.obj._get_axis_number(axis)
#     113         new_self.axis = axis
#     114         return new_self
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     409             except KeyError:
#     410                 pass
# --> 411         raise ValueError("No axis named {0} for object type {1}".format(axis, cls))
#     412
#     413     @classmethod
#
# ValueError: No axis named 1 for object type <class 'pandas.core.frame.DataFrame'>

# %%
raw_data.loc[1]
# Out:
# marketplace                                                         US
# customer_id                                                   11599505
# review_id                                                RE36JAD5V53PO
# product_id                                                  B0009XH6V4
# product_parent                                               670161917
# product_title                             andis micro turbo hair dryer
# product_category                                                Beauty
# star_rating                                                          4
# helpful_votes                                                        0
# total_votes                                                          0
# vine                                                                 N
# verified_purchase                                                    Y
# review_headline      I love travel blow dryers because they are eas...
# ...

# %%
typeof(raw_data.loc[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b68fc5ffd4f3> in <module>
# ----> 1 typeof(raw_data.loc[1])
#
# NameError: name 'typeof' is not defined

# %%
type(raw_data.loc[1])
# Out:
# pandas.core.series.Series
